# %%
# %pip install tensorflow==2.13.0
# %pip install numpy==1.24.3
# %pip install protobuf==3.20.3
# %pip install tensorflow-addons==0.21.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow==2.13.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (25.12.19)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.20.3)
# Requirement already satisfied: setuptools in c:\program files\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.3.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-intel==2.13.0->tensorflow==2.13.0)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.74.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.31.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.49.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.10.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.33.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.1.8)
# Requirement already satisfied: wheel>=0.26 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.46.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (45.0.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2026.2.25)
# Requirement already satisfied: cffi>=1.14 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from cffi>=1.14->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.0.3)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
# Successfully installed typing-extensions-4.5.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 2.17.0 requires nbconvert>=6.4.4, which is not installed.
# exceptiongroup 1.3.1 requires typing-extensions>=4.6.0; python_version < "3.13", but you have typing-extensions 4.5.0 which is incompatible.
# ipython 8.38.0 requires typing_extensions>=4.6; python_version < "3.12", but you have typing-extensions 4.5.0 which is incompatible.
# optree 0.19.0 requires typing-extensions>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy==1.24.3 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (1.24.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: protobuf==3.20.3 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (3.20.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-addons==0.21.0 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (0.21.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-addons==0.21.0) (2.13.3)
# Requirement already satisfied: packaging in c:\users\sathwik\appdata\roaming\python\python310\site-packages (from tensorflow-addons==0.21.0) (26.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# C:\Users\Sathwik\AppData\Roaming\Python\Python310\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
num_classes = 10
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 62s 0us/step
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %%
x_train = x_train[:500]
y_train = y_train[:500]
x_test = x_test[:500]
y_test = y_test[:500]

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 40
image_size = 72 # We'll resize input images to this size
patch_size = 6 # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim*2,
    projection_dim
] # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024] # Size of the dense layers of the final classifier

# %%
data_augmentation = keras.Sequential([
    layers.Normalization(),
    layers.Resizing(image_size, image_size),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(factor=0.02),
    layers.RandomZoom(
        height_factor=0.2, width_factor=0.2)
    ],
    name="data_augmentation")

data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1,1,1,1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4,4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i+1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim = num_patches, output_dim = projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple Layers of the Transformer block
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras Model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top_5_accuracy"),
        ]
    )

    checkpoint_filepath = "./tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    loss, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test Top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

# %%
vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/40
# 2/2 [==============================] - 31s 12s/step - loss: 5.7437 - accuracy: 0.1289 - top_5_accuracy: 0.5289 - val_loss: 3.3864 - val_accuracy: 0.2000 - val_top_5_accuracy: 0.7800
# Epoch 2/40
# 2/2 [==============================] - 16s 8s/step - loss: 4.8834 - accuracy: 0.2378 - top_5_accuracy: 0.6311 - val_loss: 2.8989 - val_accuracy: 0.2200 - val_top_5_accuracy: 0.6400
# Epoch 3/40
# 2/2 [==============================] - 15s 7s/step - loss: 3.4847 - accuracy: 0.2578 - top_5_accuracy: 0.7222 - val_loss: 2.2298 - val_accuracy: 0.1800 - val_top_5_accuracy: 0.7600
# Epoch 4/40
# 2/2 [==============================] - 16s 8s/step - loss: 2.9697 - accuracy: 0.2689 - top_5_accuracy: 0.7244 - val_loss: 2.1587 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.7400
# Epoch 5/40
# 2/2 [==============================] - 16s 8s/step - loss: 2.7247 - accuracy: 0.2489 - top_5_accuracy: 0.7000 - val_loss: 2.0339 - val_accuracy: 0.3200 - val_top_5_accuracy: 0.8200
# Epoch 6/40
# 2/2 [==============================] - 16s 7s/step - loss: 2.5035 - accuracy: 0.2489 - top_5_accuracy: 0.7000 - val_loss: 2.0308 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.7000
# Epoch 7/40
# 2/2 [==============================] - 15s 7s/step - loss: 2.2238 - accuracy: 0.2778 - top_5_accuracy: 0.7622 - val_loss: 1.9314 - val_accuracy: 0.2200 - val_top_5_accuracy: 0.7600
# Epoch 8/40
# 2/2 [==============================] - 15s 7s/step - loss: 2.2247 - accuracy: 0.2978 - top_5_accuracy: 0.7689 - val_loss: 1.8669 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8000
# Epoch 9/40
# 2/2 [==============================] - 16s 7s/step - loss: 2.0766 - accuracy: 0.3067 - top_5_accuracy: 0.8267 - val_loss: 1.8286 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.7800
# Epoch 10/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.9191 - accuracy: 0.3467 - top_5_accuracy: 0.8556 - val_loss: 1.8475 - val_accuracy: 0.2200 - val_top_5_accuracy: 0.7800
# Epoch 11/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.9179 - accuracy: 0.3244 - top_5_accuracy: 0.8556 - val_loss: 1.8745 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8000
# Epoch 12/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.9129 - accuracy: 0.3778 - top_5_accuracy: 0.8467 - val_loss: 1.9129 - val_accuracy: 0.2200 - val_top_5_accuracy: 0.7600
# Epoch 13/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.8457 - accuracy: 0.3778 - top_5_accuracy: 0.8489 - val_loss: 1.9181 - val_accuracy: 0.2000 - val_top_5_accuracy: 0.8000
# Epoch 14/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.7739 - accuracy: 0.3778 - top_5_accuracy: 0.8822 - val_loss: 1.8873 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8400
# Epoch 15/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.7474 - accuracy: 0.4044 - top_5_accuracy: 0.8800 - val_loss: 1.9170 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8600
# Epoch 16/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.6297 - accuracy: 0.4311 - top_5_accuracy: 0.8800 - val_loss: 1.9283 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8200
# Epoch 17/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.5771 - accuracy: 0.4556 - top_5_accuracy: 0.9044 - val_loss: 1.8796 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.7800
# Epoch 18/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.6100 - accuracy: 0.4667 - top_5_accuracy: 0.8933 - val_loss: 1.8851 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8400
# Epoch 19/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.4735 - accuracy: 0.4844 - top_5_accuracy: 0.9267 - val_loss: 1.9156 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8600
# Epoch 20/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.4011 - accuracy: 0.4889 - top_5_accuracy: 0.9267 - val_loss: 1.9504 - val_accuracy: 0.3200 - val_top_5_accuracy: 0.8200
# Epoch 21/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.2907 - accuracy: 0.5556 - top_5_accuracy: 0.9356 - val_loss: 2.0015 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8200
# Epoch 22/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.3695 - accuracy: 0.4956 - top_5_accuracy: 0.9467 - val_loss: 2.0690 - val_accuracy: 0.3200 - val_top_5_accuracy: 0.8200
# Epoch 23/40
# 2/2 [==============================] - 16s 7s/step - loss: 1.3264 - accuracy: 0.5489 - top_5_accuracy: 0.9422 - val_loss: 2.0457 - val_accuracy: 0.3200 - val_top_5_accuracy: 0.8000
# Epoch 24/40
# 2/2 [==============================] - 16s 7s/step - loss: 1.2678 - accuracy: 0.5244 - top_5_accuracy: 0.9422 - val_loss: 1.9954 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8400
# Epoch 25/40
# 2/2 [==============================] - 16s 7s/step - loss: 1.1869 - accuracy: 0.5933 - top_5_accuracy: 0.9511 - val_loss: 1.9786 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8000
# Epoch 26/40
# 2/2 [==============================] - 16s 7s/step - loss: 1.2028 - accuracy: 0.5867 - top_5_accuracy: 0.9511 - val_loss: 1.9733 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8400
# Epoch 27/40
# 2/2 [==============================] - 16s 7s/step - loss: 1.0627 - accuracy: 0.6111 - top_5_accuracy: 0.9689 - val_loss: 2.0590 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8200
# Epoch 28/40
# 2/2 [==============================] - 16s 7s/step - loss: 1.0586 - accuracy: 0.6356 - top_5_accuracy: 0.9733 - val_loss: 2.1703 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8000
# Epoch 29/40
# 2/2 [==============================] - 15s 7s/step - loss: 0.9907 - accuracy: 0.6356 - top_5_accuracy: 0.9644 - val_loss: 2.2956 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8000
# Epoch 30/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.1058 - accuracy: 0.6089 - top_5_accuracy: 0.9667 - val_loss: 2.2015 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.7800
# Epoch 31/40
# 2/2 [==============================] - 15s 7s/step - loss: 1.0357 - accuracy: 0.6622 - top_5_accuracy: 0.9778 - val_loss: 2.2330 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8000
# Epoch 32/40
# 2/2 [==============================] - 15s 7s/step - loss: 0.9198 - accuracy: 0.6533 - top_5_accuracy: 0.9756 - val_loss: 2.3145 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8200
# Epoch 33/40
# 2/2 [==============================] - 16s 7s/step - loss: 0.9982 - accuracy: 0.6244 - top_5_accuracy: 0.9756 - val_loss: 2.3501 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8200
# Epoch 34/40
# 2/2 [==============================] - 15s 7s/step - loss: 0.8457 - accuracy: 0.7089 - top_5_accuracy: 0.9778 - val_loss: 2.3688 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8400
# Epoch 35/40
# 2/2 [==============================] - 15s 7s/step - loss: 0.8591 - accuracy: 0.6911 - top_5_accuracy: 0.9800 - val_loss: 2.3776 - val_accuracy: 0.3200 - val_top_5_accuracy: 0.8400
# Epoch 36/40
# 2/2 [==============================] - 15s 7s/step - loss: 0.8009 - accuracy: 0.7489 - top_5_accuracy: 0.9844 - val_loss: 2.3511 - val_accuracy: 0.3200 - val_top_5_accuracy: 0.8800
# Epoch 37/40
# 2/2 [==============================] - 16s 7s/step - loss: 0.7143 - accuracy: 0.7333 - top_5_accuracy: 0.9933 - val_loss: 2.4187 - val_accuracy: 0.3200 - val_top_5_accuracy: 0.8600
# Epoch 38/40
# 2/2 [==============================] - 15s 7s/step - loss: 0.7499 - accuracy: 0.7267 - top_5_accuracy: 0.9867 - val_loss: 2.5286 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.9000
# Epoch 39/40
# 2/2 [==============================] - 16s 8s/step - loss: 0.7252 - accuracy: 0.7444 - top_5_accuracy: 0.9867 - val_loss: 2.5843 - val_accuracy: 0.3400 - val_top_5_accuracy: 0.8600
# Epoch 40/40
# 2/2 [==============================] - 15s 7s/step - loss: 0.6716 - accuracy: 0.7578 - top_5_accuracy: 0.9867 - val_loss: 2.6780 - val_accuracy: 0.3200 - val_top_5_accuracy: 0.8600
# 16/16 [==============================] - 7s 428ms/step - loss: 2.4925 - accuracy: 0.3440 - top_5_accuracy: 0.8480
# Test accuracy: 34.4%
# Test Top 5 accuracy: 84.8%

# %%
class_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]

# %%
def img_predict(images, model):
    # 1. Fix the shape if it's a single image
    if len(images.shape) == 3:
        images = images.reshape(-1, *images.shape)
    
    # 2. Make the prediction (this now runs no matter what!)
    out = model.predict(images)
    
    # 3. Process the output
    prediction = np.argmax(out, axis = 1)
    img_prediction = [class_names[i] for i in prediction]
    
    return img_prediction

# %%
import random
import matplotlib.pyplot as plt

# Pick a random number between 0 and the total number of test images
index = random.randint(0, len(x_test) - 1)

# Get the image and predict
image = x_test[index]
prediction = img_predict(image, vit_classifier)

# Display it nicely
plt.imshow(image)
plt.title(f"Model Prediction: {prediction[0]}") # Shows prediction as the title
plt.axis('off') # Hides the ugly axis numbers
plt.show() # Forces Jupyter to render the image right now
# Out:
# 1/1 [==============================] - 0s 43ms/step
